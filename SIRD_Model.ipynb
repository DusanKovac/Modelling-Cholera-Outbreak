# %% [markdown]
# # SIRD Model

# %% [markdown]
# ### Set up and Data Processing

# %%
import numpy as np
import pandas as pd
from scipy.integrate import solve_ivp
from scipy.optimize import minimize
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from lmfit import minimize, Parameters, Parameter

# %%
# Handle data
# We are given the initial number of dead people, 22
# Assuming that 1% of cases result in death, this gives us an initial removed number of 22*100

who_data = pd.read_csv('cholera_data.csv')

N = 44970000 #South African population in 2000, according to https://data.worldbank.org/indicator/SP.POP.TOTL?locations=ZA

S_data = np.array( ( who_data.iloc[:,0]*(-1) + N ) / N )
R_data = np.array( ( who_data.iloc[:,1]*100 ) / N )
I_data = np.array( 1 - S_data - R_data )
D_data = np.array( ( who_data.iloc[:,1] ) / N )

times = who_data.iloc[:,2]

I0 = who_data.iloc[0, 0] / N
S0 = (N - who_data.iloc[0,0])  / N
R0 = 22*100/N
D0 = 22/N

# %% [markdown]
# ### Base Model:

# %%
def SIRD_model(y,t,alpha,beta,mu):
    S, I, R, D = y
    dSdt = -beta*S*I 
    dIdt = beta*S*I - alpha*I - mu*I 
    dRdt = alpha*I 
    dDdt = mu*I 
    
    return dSdt, dIdt, dRdt, dDdt

# %%
# code modified from https://towardsdatascience.com/estimating-parameters-of-compartmental-models-from-observed-data-62f87966bb2b
# initial guesses for parameters
alpha = 0.1
beta = 0.1

# other model parameters
initial_conditions = [S0, I0, R0, D0]
num_days = 15
tspan = times[0:num_days]

# I'm sure there is a cleaner way to do this
data = np.concatenate((S_data[0:num_days], I_data[0:num_days], R_data[0:num_days], D_data[0:num_days]))
# data = np.concatenate((S_data[0:num_days], I_data[0:num_days]))

def error(params, initial_conditions, tspan, data):
    alpha, beta, mu = params['alpha'].value, params['beta'].value, params['mu'].value
    sol = np.array(odeint(SIRD_model, [S0, I0, R0, D0], tspan, args=(alpha, beta, mu)))
    # sol_1d = np.concatenate((np.array(sol[:,0]),np.array(sol[:,1])))
    sol_1d = np.concatenate((np.array(sol[:,0]),np.array(sol[:,1]),np.array(sol[:,2]),np.array(sol[:,3])))
    return pow(sol_1d - data, 2)

params = Parameters()
params.add('beta', value=beta, min=0, max=10)
params.add('alpha', value=alpha, min=0, max=10)
params.add('mu', value=alpha, min=0, max=10)

result = minimize(error, params, args=(initial_conditions, tspan, data), method='leastsq')

# %%
# beta = 0.02869
# alpha =0.006409

alpha = result.params['alpha'].value
beta = result.params['beta'].value
mu = result.params['mu'].value

print("Optimal Parameters: \nalpha =", alpha, "\nbeta =", beta, "\nmu =", mu)

t = np.linspace(0, 1000, 1000)

sol = np.array(odeint(SIRD_model, [S0, I0, R0, D0], t, args=(alpha, beta, mu)))
S_model = sol[:,0]
I_model = sol[:,1]
R_model = sol[:,2]
D_model = sol[:,3]
# Out:
# Optimal Parameters:
# alpha = 0.007477567513012873
# beta = 0.029967408628620573
# mu = 0.0013582466192069154

# %%
# Plot susceptibles
p = plt.figure(figsize = [6,4])

plt.plot(t[0:200], S_model[0:200], label = "Model")
plt.plot(times, S_data, label = "Truth") 

plt.grid()
plt.legend()
plt.xlabel("time")
plt.ylabel("% of population susceptible")
plt.title("Suscpetible")
plt.ylim(0.995,1)
plt.show()

# Plot infected
p = plt.figure(figsize = [6, 4])

plt.plot(t[0:200], I_model[0:200], label = "Model")
plt.plot(times, I_data, label = "Truth") 

plt.grid()
plt.legend()
plt.xlabel("time")
plt.ylabel("% of population Infected")
plt.title("Infections")
plt.show()

# Plot deceased
p = plt.figure(figsize = [6, 4])

plt.plot(t[0:200], D_model[0:200], label = "Model")
plt.plot(times, D_data, label = "Truth") 

plt.grid()
plt.legend()
plt.xlabel("time")
plt.ylabel("% of population deceased")
plt.title("Deaths")
plt.show()

# %% [markdown]
# ### Model with Control Mechanisms

# %%
def SIRD_model(y,t,alpha,beta, mu, c):
    S, I, R, D = y
    dSdt = -(beta)*S*I + c*I*R
    dIdt = (beta)*S*I - alpha*I - mu*I  - c*I*R
    dRdt = alpha*I 
    dDdt = mu*I 
    
    return dSdt, dIdt, dRdt, dDdt

# %%
# code modified from https://towardsdatascience.com/estimating-parameters-of-compartmental-models-from-observed-data-62f87966bb2b
# initial guesses for parameters
alpha = 0.1
beta = 0.1
mu = 0.1
h = 0.1
c = 0.1
phi = 0.1

# other model parameters
initial_conditions = [S0, I0, R0, D0]
num_days = 21
tspan = times[0:num_days]

# I'm sure there is a cleaner way to do this
data = np.concatenate((S_data[0:num_days], I_data[0:num_days], R_data[0:num_days], D_data[0:num_days]))
# data = np.concatenate((S_data[0:num_days], I_data[0:num_days]))

def error(params, initial_conditions, tspan, data):
    alpha, beta, mu, c = params['alpha'].value, params['beta'].value, params['mu'].value, params['c'].value
    sol = np.array(odeint(SIRD_model, [S0, I0, R0, D0], tspan, args=(alpha, beta, mu,c)))
    # sol_1d = np.concatenate((np.array(sol[:,0]),np.array(sol[:,1])))
    sol_1d = np.concatenate((np.array(sol[:,0]),np.array(sol[:,1]),np.array(sol[:,2]),np.array(sol[:,3])))
    return pow(sol_1d - data,2)

params = Parameters()
params.add('beta', value=beta, min=0, max=10)
params.add('alpha', value=alpha, min=0, max=10)
params.add('mu', value=alpha, min=0, max=10)
params.add('c', value=alpha, min=0, max=10)

result = minimize(error, params, args=(initial_conditions, tspan, data), method='leastsq')

# %%
# beta = 0.02869
# alpha =0.006409

alpha = result.params['alpha'].value
beta = result.params['beta'].value
mu = result.params['mu'].value
c = result.params['c'].value

print("Optimal Parameters: \nalpha =", alpha, "\nbeta =", beta, "\nmu =", mu, "\nc =", c, )

t = np.linspace(0, 1000, 1000)

sol = np.array(odeint(SIRD_model, [S0, I0, R0, D0], t, args=(alpha, beta, mu, c)))
S_model = sol[:,0]
I_model = sol[:,1]
R_model = sol[:,2]
D_model = sol[:,3]
# Out:
# Optimal Parameters:
# alpha = 0.006571581156066264
# beta = 0.02792664191293648
# mu = 0.00010075689548472155
# c = 9.999328126584006

# %%
# Plot susceptibles
p = plt.figure(figsize = [6,4])

plt.plot(t[0:200], S_model[0:200], label = "Model")
plt.plot(times, S_data, label = "Truth") 

plt.grid()
plt.legend()
plt.xlabel("time")
plt.ylabel("% of population susceptible")
plt.title("Suscpetible")
plt.ylim(0.995,1)
plt.show()

# Plot infected
p = plt.figure(figsize = [6, 4])

plt.plot(t[0:200], I_model[0:200], label = "Model")
plt.plot(times, I_data, label = "Truth") 

plt.grid()
plt.legend()
plt.xlabel("time")
plt.ylabel("% of population Infected")
plt.title("Infections")
plt.show()
# Plot recovered
p = plt.figure(figsize = [6, 4])

plt.plot(t[0:200], R_model[0:200], label = "Model")
plt.plot(times, R_data, label = "Truth") 

plt.grid()
plt.legend()
plt.xlabel("time")
plt.ylabel("% of population Recovered")
plt.title("Recovered")
plt.show()

# Plot deceased
p = plt.figure(figsize = [6, 4])

plt.plot(t[0:200], D_model[0:200], label = "Model")
plt.plot(times, D_data, label = "Truth") 

plt.grid()
plt.legend()
plt.xlabel("time")
plt.ylabel("% of population deceased")
plt.title("Deaths")
plt.show()
